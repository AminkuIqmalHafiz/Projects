# %% [markdown]
# # **Result and Conclusion** - **Using Random Forest Regressor to Estimate Density-Porosity Well Log Readings**

# %% [markdown]
# #### **Result Evaluation**
# - I use 2 metrics to decide the estimator's performance :
#     1) R2 score
#         - R2 measures how much is the ML's performance against the scenario of only predict using the mean value.
#     2) Mean Squared Error (MSE)
#         - MSE measures how much our prediction deviates from the actual testing data.

# %% [markdown]
# #### **Training Result**

# %% [raw]
# Best Parameters: {'max_depth': None, 'max_features': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
# Train R2 Score: 0.9947914850535767
# MSE(Train): 3.0780074613006456

# %% [markdown]
# #### **Testing Result**

# %% [raw]
# Test R2 Score: 0.9742396005291164
# MSE(Test): 15.220790477057761

# %% [markdown]
# #### **GridSearchCV's verdict on the parameter :**
#  - n_estimator : 200
#  - max_depth : None
#  - max_features : None
#  - min_samples_leaf : 2
#  - min_sample_split : 2
#
# #### **Conclusion**
# The parameter was decided based on which is the best perform on this particular dataset. In this case, we can observe that our estimator are using high number of estimator to justify deep consensus being made to predict DPOR. Other than that, it turns out both max_depth and max_features are none, proving that all 9 well logs are substantially significant for tree-based algorithm while needed a sophisticated depth to get the best performance.
# The cross-validation also picked up the least value for min_samples_lead and min_sample_split, meaning that, it prefers a very deep splitting in order for the parameters to be understand enough by the estimator.
# Overall, our estimator manage to give out an impressive result of **Test R2 Score : 0.9742**, which means our model are able to justify 97.42% of the well logs' wild variance.
